# %%
base = "/Workspace/Users/pakshal2501@gmail.com/Databricks_Project_2026/bike_lakehouse_2026"

notebooks = [
    f"{base}/silver_crm_cust_info",
    f"{base}/silver_crm_prd_info",
    f"{base}/silver_crm_sales_details",
    f"{base}/silver_erp_cust_az12",
    f"{base}/silver_erp_loc_a101",
    f"{base}/silver_erp_px_cat_g1v2",
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
